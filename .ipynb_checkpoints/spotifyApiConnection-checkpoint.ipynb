# %%
import requests
import pandas as pd
from urllib.request import Request, urlopen
from sodapy import Socrata
import json
import re
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import ipywidgets as wd
from ipywidgets import interact
import seaborn as sns
#import ptitprince as pt
import base64

# %%
with open("newSecret.json", "r") as f:
    config = json.load(f)

token = config["TOKEN_API_OD"]
user=config["user"]
passwd=config["pw"]
client_id=config["clientId"]
client_secret=config["clientSecret"]

# %%
def get_access_token(client_id, client_secret):
    # URL para obtener el token de acceso
    auth_url = 'https://accounts.spotify.com/api/token'
    
    # Creación del encabezado de autorización con client_id y client_secret codificados en base64
    auth_header = {
        'Authorization': f'Basic {base64.b64encode((client_id + ":" + client_secret).encode()).decode()}'
    }
    
    # Datos necesarios para la petición POST
    auth_data = {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret
    }
    
    # Realizar la petición POST
    auth_response = requests.post(auth_url, data=auth_data, headers=auth_header)
    
    # Extraer la respuesta y obtener el token de acceso
    auth_response_data = auth_response.json()
    access_token = auth_response_data['access_token']
    
    # Devolver el token de acceso
    return access_token

# %%
def get_genres(access_token, limit=50, offset=0):
    genres_url = 'https://api.spotify.com/v1/browse/categories'
    
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    
    params = {
        'limit': limit,
        'offset': offset
    }
    
    # Realiza la petición GET a la API de Spotify para obtener los géneros
    response = requests.get(genres_url, headers=headers, params=params)
    
    # Extrae la respuesta y convierte el JSON en un diccionario de Python
    genres_data = response.json()
    
    # Crea una lista de tuplas, donde cada tupla contiene el ID del género y su nombre
    genres = [(category['id'], category['name']) for category in genres_data['categories']['items']]
    
    return genres

# %%
access_token = get_access_token(client_id, client_secret)  # Suponiendo que ya has definido client_id y client_secret
genres_list = get_genres(access_token)

# Crear un DataFrame a partir de la lista de géneros
df_genres = pd.DataFrame(genres_list, columns=['Genre_ID', 'Genre_Name'])

# %%
df_genres
# Out:
#                   Genre_ID          Genre_Name
# 0                 toplists           Top Lists
# 1   0JQ5DAqbMKFGcCCKMatU5w    Made in Colombia
# 2   0JQ5DAqbMKFPw634sFwguI               EQUAL
# 3   0JQ5DAqbMKFOOxftoKZxod               RADAR
# 4   0JQ5DAqbMKFF9bY76LXmfI           Frequency
# 5   0JQ5DAqbMKFx0uLQR2okcc             At Home
# 6   0JQ5DAqbMKFLb2EqgLtpjC            Wellness
# 7   0JQ5DAqbMKFCbimwdOYlsl               Focus
# 8   0JQ5DAqbMKFxXaXKP7zcDp               Latin
# 9   0JQ5DAqbMKFEC4WFtoNRpw                 Pop
# 10  0JQ5DAqbMKFFzDl7qN9Apr               Chill
# 11  0JQ5DAqbMKFDTEtSaS4R92    Regional Mexican
# 12  0JQ5DAqbMKFDXXwE9BDJAr                Rock
# 13  0JQ5DAqbMKFzHmL4tf05da                Mood
# 14  0JQ5DAqbMKFCuoRTxhYWow               Sleep
# 15  0JQ5DAqbMKFAXlCG6QvYQ4             Workout
# 16  0JQ5DAqbMKFA6SOHvT3gck               Party
# 17  0JQ5DAqbMKFFtlLYUHv8bT         Alternative
# 18  0JQ5DAqbMKFRKBHIxJ5hMm         Tastemakers
# 19  0JQ5DAqbMKFIVNxQgRNSg0             Decades
# 20  0JQ5DAqbMKFCWjUTdzaG0e               Indie
# 21  0JQ5DAqbMKFQIL0AXnG5AK            Trending
# 22  0JQ5DAqbMKFHOzuVTgTizF    Dance/Electronic
# 23  0JQ5DAqbMKFEZPnFQSFB1T                 R&B
# 24  0JQ5DAqbMKFRY5ok2pxXJ0    Cooking & Dining
# 25  0JQ5DAqbMKFQ00XGBls6ym             Hip-Hop
# 26  0JQ5DAqbMKFObNLOHydSW8           Caribbean
# 27  0JQ5DAqbMKFKLfwjuJMoNC             Country
# 28  0JQ5DAqbMKFy0OenPG51Av  Christian & Gospel
# 29  0JQ5DAqbMKFy78wprEpAjl     Folk & Acoustic
# 30  0JQ5DAqbMKFDkd668ypn6O               Metal
# 31  0JQ5DAqbMKFIpEuaCnimBj                Soul
# 32  0JQ5DAqbMKFAQy4HL4XU2D              Travel
# 33  0JQ5DAqbMKFAJ5xb0fwo9m                Jazz
# 34  0JQ5DAqbMKFQiK2EHwyjcU               Blues
# 35  0JQ5DAqbMKFAjfauKLOZiv                Punk
# 36  0JQ5DAqbMKFAUsdyVjCQuL             Romance
# 37                    funk                Funk
# 38  0JQ5DAqbMKFPrEiAOxgac3           Classical
# 39                  comedy              Comedy
# 40  0JQ5DAqbMKFFoimhOqWzLB       Kids & Family
# 41  0JQ5DAqbMKFCfObibaOZbv              Gaming
# 42  0JQ5DAqbMKFNT6Du8qM9kt     Brazilian music
# 43  0JQ5DAqbMKFNQ0fGp4byGU                Afro
# 44  0JQ5DAqbMKFGvOw3O4nLAf               K-Pop
# 45  0JQ5DAqbMKFQFQN0rnK48G            Flamenco
# 46      listening_together  Listening Together
# 47  0JQ5DAqbMKFLVaM30PMBm4              Summer
# 48  0JQ5DAqbMKFRieVZLLoo9m        Instrumental
# 49  0JQ5DAqbMKFLjmiZRss79w             Ambient

# %%
def extract_artists_to_dataframe(response_data):
    # Lista para almacenar datos de artistas
    artist_list = []

    # Iterar sobre cada artista en la respuesta
    for artist in response_data['artists']:
        # Extraer la información relevante
        artist_info = {
            'Name': artist['name'],
            'Genres': ', '.join(artist['genres']),
            'Popularity': artist['popularity'],
            'Spotify_URL': artist['external_urls']['spotify'],
            'Followers': artist['followers']['total'],
            'Image_URL': artist['images'][0]['url'] if artist['images'] else None, # Toma la primera imagen, si existe
            'Artist_ID': artist['id'],
            'Artist_Type': artist['type'],
            'Artist_URI': artist['uri']
        }
        # Agregar a la lista
        artist_list.append(artist_info)

    # Convertir lista en DataFrame
    df_artists = pd.DataFrame(artist_list)

    return df_artists

# %%
def get_artists_from_spotify(token, artist_ids):
    """
    Fetch artist details from Spotify's API.
    
    :param access_token: Token for API authorization.
    :param artist_ids: List of artist IDs.
    :return: Response data as a dictionary.
    """
    
    # Endpoint de la API
    base_url = "https://api.spotify.com/v1/artists"
    
    # Headers de la petición (incluye el token de acceso para autorización)
    headers = {
        "Authorization": f"Bearer {token}"
    }
    
    # Parámetros de la petición (IDs de los artistas)
    params = {
        "ids": ",".join(artist_ids)
    }
    
    # Realizar la petición GET a la API de Spotify
    response = requests.get(base_url, headers=headers, params=params)
    
    # Convertir la respuesta en formato JSON a un diccionario de Python
    response_data = response.json()

    return response_data

# Ejemplo de uso:

artist_ids = ["2CIMQHirSU0MQqyYHq0eOx", "57dN52uHvrHOxijzpIgu3E"]  # Reemplaza con los IDs de los artistas que quieras consultar
token=access_token
# Obtener respuesta de la API
response_data = get_artists_from_spotify(token, artist_ids)

# Procesar la respuesta con la función extract_artists_to_dataframe
df_artist = extract_artists_to_dataframe(response_data)
#print(df)
df_artist
# Out:
#        Name                                             Genres  Popularity  \
# 0  deadmau5  canadian electronic, complextro, edm, electro ...          65
# 1   Ratatat                                       indietronica          63
#
#                                          Spotify_URL  Followers  \
# 0  https://open.spotify.com/artist/2CIMQHirSU0MQq...    2825611
# 1  https://open.spotify.com/artist/57dN52uHvrHOxi...     595231
#
#                                            Image_URL               Artist_ID  \
# 0  https://i.scdn.co/image/ab6761610000e5ebc5ceb0...  2CIMQHirSU0MQqyYHq0eOx
# 1  https://i.scdn.co/image/2f0c6c465a83cd196e651e...  57dN52uHvrHOxijzpIgu3E
#
#   Artist_Type                             Artist_URI
# 0      artist  spotify:artist:2CIMQHirSU0MQqyYHq0eOx
# 1      artist  spotify:artist:57dN52uHvrHOxijzpIgu3E

# %%
import requests

def get_artists_by_genre(query, access_token, limit=50):
    search_url = 'https://api.spotify.com/v1/search'
    
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    
    params = {
        'q': f"genre:\"{query}\"",
        'type': 'artist',
        'limit': limit
    }
    
    response = requests.get(search_url, headers=headers, params=params)
    response_data = response.json()
    
    if 'artists' in response_data:
        return [artist['id'] for artist in response_data['artists']['items']]
    else:
        print("Error en la respuesta de la API:", response_data)
        return []

# %%
genre = "death metal"
metal_artist_ids = get_artists_by_genre(genre, access_token)
print(metal_artist_ids)
# Out:
# ['1IQ2e1buppatiN1bxUVkrk', '5pqvAI85RMxL9K0xHvSwGu', '0GDGKpJFhVpcjIGF8N6Ewt', '57ylwQTnFnIhJh4nu4rxCs', '6vXYoy8ouRVib302zxaxFF', '24Oiw7BlvO1BETecDLJt6m', '1C62FV9Cltn9L4c9jAwCyk', '3pulcT2wt7FEG10lQlqDJL', '3iCJOi5YKh247eutgCyLFe', '6JW8wliOEwaDZ231ZY7cf4', '0FZcPgWI3BsFQl4rOAGSHT', '2tjnvrUmP46XNjFh9V0NGc', '4Uv5bceTJ2h3tLlssUNDNP', '0yLwGBQiBqhXOvmTfH2A7n', '4f5V3PQ66nIrBCqugJtaGn', '5274obTQJjzjyycRyJlfml', '2OTuoIi28WybVbVcykc237', '6HZr7Fs2VfV1PYHIwo8Ylc', '4d6Rawrese4OLF1zZCztod', '4UgQ3EFa8fEeaIEg54uV5b', '0ybFZ2Ab08V8hueghSXm6E', '3et9upNERQI5IYt5jEDTxM', '1xUhNgw4eJDZfvumIpcz1B', '2i7CQcVBh2K6uOR3CH09M1', '0DCw6lHkzh9t7f8Hb4Z0Sx', '4tDkeVxH0CSkNiLVrsYmQs', '1DgmdsnwOexqTH8ohPCFAU', '1AdrYGYDz4oa9dvW2jfFrG', '0uNj4RxFjG0iVPlZS753en', '1bPBx2qbpWzEoLujeHC3G7', '0qJpY7K8p7g6sacvaGNt6i', '2Ah9OuOj7B57gPD1cbwiaE', '7k29FbDq69ju2fe6zTskxY', '4xTDPgk4jHCF0qui3dH6BS', '7wqP36o9lqWteOCxBnXlwx', '76xrrejizyQpKukBIhnf3D', '67ZMMtA88DDO0gTuRrzGjn', '76S65NHJHrNy4JTrXHP2BH', '4HgqjpBaWctBWVHafQIpRt', '6EFV3PmaXblKwNbvpkGv9l', '6e8ISIsI7UQZPyEorefAhK', '2DynE7m1BMVl4hQMvCXXq0', '36d1uVy1ZuZWqfnsPxCUOk', '3BM0EaYmkKWuPmmHFUTQHv', '5ZvwJikDgdP1PFU4PkAPVG', '55b0Gfm53udtGBs8mmNXrH', '2DqzOWVL2ly48IA9bpZdie', '4DSNcg40nf6T3eNAObq1Lo', '1MK0sGeyTNkbefYGj673e9', '5lhaM01nwvsMZpmPY2HVER']

# %%
#artist_ids = ["2CIMQHirSU0MQqyYHq0eOx", "57dN52uHvrHOxijzpIgu3E"]  # Reemplaza con los IDs de los artistas que quieras consultar
token=access_token
# Obtener respuesta de la API
response_data = get_artists_from_spotify(token, metal_artist_ids)

# Procesar la respuesta con la función extract_artists_to_dataframe
df_metal_artist = extract_artists_to_dataframe(response_data)
#print(df)
df_metal_artist
# Out:
#                        Name  \
# 0                    Slayer
# 1                  Currents
# 2                    Gojira
# 3                 In Flames
# 4               Lorna Shore
# 5      Slaughter to Prevail
# 6                    Emmure
# 7               Amon Amarth
# 8               I See Stars
# 9                 Sepultura
# 10         Make Them Suffer
# 11               Alpha Wolf
# 12                   Attila
# 13          Cannibal Corpse
# 14                    Death
# 15              Whitechapel
# 16               Miss May I
# 17          Suicide Silence
# 18       Brand of Sacrifice
# 19             Chelsea Grin
# 20                    Opeth
# 21        Thy Art Is Murder
# 22        Children Of Bodom
# 23             Veil Of Maya
# 24               Arch Enemy
# 25        The Acacia Strain
# 26                  Volumes
# 27               Angelmaker
# 28         After The Burial
# 29      Upon A Burning Body
# 30       Fit For An Autopsy
# 31          Municipal Waste
# 32            Orbit Culture
# 33  The Black Dahlia Murder
# 34                 Soilwork
# 35         Shadow of Intent
# 36      Cattle Decapitation
# 37                   Exodus
# 38           Born Of Osiris
# 39                  Varials
# 40             Dimmu Borgir
# 41                    Spite
# 42           Left to Suffer
# 43                  Kreator
# 44        Bleed From Within
# 45               Norma Jean
# 46              Dying Fetus
# 47             The Browning
# 48                 Behemoth
# 49                  Carcass
#
#                                                Genres  Popularity  \
# 0   alternative metal, death metal, groove metal, ...          65
# 1   melodic metalcore, metalcore, progressive deat...          59
# 2   alternative metal, french death metal, french ...          62
# 3   alternative metal, gothenburg metal, melodic d...          62
# 4   blackened deathcore, melodic metalcore, sympho...          58
# 5   russian metal, russian metalcore, slamming dea...          57
# 14      artist  spotify:artist:4f5V3PQ66nIrBCqugJtaGn
# 15      artist  spotify:artist:5274obTQJjzjyycRyJlfml
# 16      artist  spotify:artist:2OTuoIi28WybVbVcykc237
# 17      artist  spotify:artist:6HZr7Fs2VfV1PYHIwo8Ylc
# 18      artist  spotify:artist:4d6Rawrese4OLF1zZCztod
# 19      artist  spotify:artist:4UgQ3EFa8fEeaIEg54uV5b
# 20      artist  spotify:artist:0ybFZ2Ab08V8hueghSXm6E
# 21      artist  spotify:artist:3et9upNERQI5IYt5jEDTxM
# 22      artist  spotify:artist:1xUhNgw4eJDZfvumIpcz1B
# 23      artist  spotify:artist:2i7CQcVBh2K6uOR3CH09M1
# 24      artist  spotify:artist:0DCw6lHkzh9t7f8Hb4Z0Sx
# 25      artist  spotify:artist:4tDkeVxH0CSkNiLVrsYmQs
# 26      artist  spotify:artist:1DgmdsnwOexqTH8ohPCFAU
# 27      artist  spotify:artist:1AdrYGYDz4oa9dvW2jfFrG
# 28      artist  spotify:artist:0uNj4RxFjG0iVPlZS753en
# 29      artist  spotify:artist:1bPBx2qbpWzEoLujeHC3G7
# 30      artist  spotify:artist:0qJpY7K8p7g6sacvaGNt6i
# 31      artist  spotify:artist:2Ah9OuOj7B57gPD1cbwiaE
# 32      artist  spotify:artist:7k29FbDq69ju2fe6zTskxY
# 33      artist  spotify:artist:4xTDPgk4jHCF0qui3dH6BS
# 34      artist  spotify:artist:7wqP36o9lqWteOCxBnXlwx
# 35      artist  spotify:artist:76xrrejizyQpKukBIhnf3D
# 36      artist  spotify:artist:67ZMMtA88DDO0gTuRrzGjn
# 37      artist  spotify:artist:76S65NHJHrNy4JTrXHP2BH
# 38      artist  spotify:artist:4HgqjpBaWctBWVHafQIpRt
# 39      artist  spotify:artist:6EFV3PmaXblKwNbvpkGv9l
# 40      artist  spotify:artist:6e8ISIsI7UQZPyEorefAhK
# 41      artist  spotify:artist:2DynE7m1BMVl4hQMvCXXq0
# 42      artist  spotify:artist:36d1uVy1ZuZWqfnsPxCUOk
# 43      artist  spotify:artist:3BM0EaYmkKWuPmmHFUTQHv
# 44      artist  spotify:artist:5ZvwJikDgdP1PFU4PkAPVG
# 45      artist  spotify:artist:55b0Gfm53udtGBs8mmNXrH
# 46      artist  spotify:artist:2DqzOWVL2ly48IA9bpZdie
# 47      artist  spotify:artist:4DSNcg40nf6T3eNAObq1Lo
# 48      artist  spotify:artist:1MK0sGeyTNkbefYGj673e9
# 49      artist  spotify:artist:5lhaM01nwvsMZpmPY2HVER

# %%
def get_artists_by_genre(query, access_token, total_limit=3000):
    search_url = 'https://api.spotify.com/v1/search'
    headers = {'Authorization': f'Bearer {access_token}'}

    MetaL_artist_ids = []
    limit = 50  # Máximo permitido por Spotify
    offset = 0  # Iniciar en el primer resultado

    while len(artist_ids) < total_limit:
        params = {
            'q': f"genre:\"{query}\"",
            'type': 'artist',
            'limit': limit,
            'offset': offset
        }

        response = requests.get(search_url, headers=headers, params=params)
        
        # Verificar la respuesta antes de intentar decodificar JSON
        if response.status_code != 200:
            print(f"Error en la solicitud: {response.status_code}")
            break

        response_data = response.json()
        
        # Verificar si hay artistas en la respuesta
        if 'artists' in response_data and 'items' in response_data['artists']:
            batch_ids = [artist['id'] for artist in response_data['artists']['items']]
            MetaL_artist_ids.extend(batch_ids)
            
            # Si se recuperaron menos artistas de los esperados, podría ser la última página
            if len(batch_ids) < limit:
                print("Alcanzado el final de los resultados.")
                break
        else:
            print("No se encontraron más artistas o hay un error en la respuesta.")
            break

        # Incrementar el offset para la siguiente tanda de resultados
        offset += limit

        # Opcional: Agregar un pequeño retraso entre las solicitudes para evitar ser bloqueado por la API por exceso de solicitudes
       # time.sleep(1)

    return MetaL_artist_ids[:total_limit]  # Devolver hasta el límite total deseado

# %%
genre = "Djent"
MetaL_artist_ids = get_artists_by_genre(genre, access_token, total_limit=3000)
print(len(MetaL_artist_ids))  # Esto debería imprimir el número de artist IDs recopilados, hasta un máximo de 9000.
# Out:
# Alcanzado el final de los resultados.
# 252

# %%
def extract_artists_to_dataframe2(artist_list):
    # Lista para almacenar los datos formateados de los artistas
    formatted_artist_data = []

    # Iterar sobre cada artista en la lista proporcionada
    for artist in artist_list:
        # Extraer la información relevante
        artist_info = {
            'Name': artist['name'],
            'Genres': ', '.join(artist['genres']),
            'Popularity': artist['popularity'],
            'Followers': artist['followers']['total'],
            'Artist_URI': artist['uri']
        }
        # Agregar a la lista
        formatted_artist_data.append(artist_info)

    # Convertir la lista de diccionarios en un DataFrame
    df_artist = pd.DataFrame(formatted_artist_data)
    return df_artist

# %%
from time import sleep

def get_artists_from_spotify2(token, artist_ids, batch_size=50):
    """
    Fetch artist details from Spotify's API in batches.
    
    :param access_token: Token for API authorization.
    :param artist_ids: List of artist IDs.
    :param batch_size: Size of the artist ID batches to request.
    :return: List of artist data dictionaries.
    """
    # Endpoint de la API
    base_url = "https://api.spotify.com/v1/artists"
    
    # Lista para almacenar todos los datos de los artistas
    all_artist_data = []
    
    # Dividir la lista de IDs en batches
    for i in range(0, len(artist_ids), batch_size):
        batch = artist_ids[i:i+batch_size]
        
        # Headers de la petición (incluye el token de acceso para autorización)
        headers = {
            "Authorization": f"Bearer {token}"
        }
        
        # Parámetros de la petición (IDs de los artistas)
        params = {
            "ids": ",".join(batch)
        }
        
        # Realizar la petición GET a la API de Spotify
        response = requests.get(base_url, headers=headers, params=params)
        
        # Verificar el estado de la respuesta
        if response.status_code == 200:
            # Convertir la respuesta en formato JSON a un diccionario de Python
            batch_data = response.json()
            all_artist_data.extend(batch_data['artists'])
        else:
            print(f"Error en el batch {i//batch_size}: {response.status_code}")
            sleep(1)  # Esperar un segundo antes de continuar para no sobrecargar la API
        
    return all_artist_data

# %%
batch_size = 50  # Spotify API limit
df_METAL_artists = pd.DataFrame()  # DataFrame vacío para almacenar los datos

# Procesar los artist IDs en batches
for i in range(0, len(MetaL_artist_ids), batch_size):
    batch_ids = MetaL_artist_ids[i:i+batch_size]
    batch_data = get_artists_from_spotify2(token, batch_ids, batch_size)
    df_batch = extract_artists_to_dataframe2(batch_data)  # Asumiendo que esta función ya está definida
    df_METAL_artists = pd.concat([df_METAL_artists, df_batch], ignore_index=True)

#print(df_artists)

# %%
df_METAL_artists
# Out:
#                        Name  \
# 0               Mick Gordon
# 1                 Meshuggah
# 2                 Periphery
# 3                      ERRA
# 4            Invent Animate
# ..                      ...
# 247        Andre Casagrande
# 248  My Home, The Catacombs
# 249                  Sashko
# 250                  Hostin
# 251                  Gnosis
#
#                                                 Genres  Popularity  Followers  \
# 0                   electronic djent, video game music          58     402415
# 1    alternative metal, djent, groove metal, metal,...          53     663869
# 2    djent, melodic metalcore, progressive metal, p...          52     478882
# 3    alabama metal, djent, melodic metalcore, metal...          49     246461
# 4    american metalcore, djent, melodic metalcore, ...          49     118850
# ..                                                 ...         ...        ...
# 247                                 instrumental djent           1        696
# 248                                   electronic djent           0        623
# 249                                 instrumental djent           2        776
# 250                                 instrumental djent           0        308
# 251                                 instrumental djent           0        103
#
#                                 Artist_URI
# 0    spotify:artist:13ab1LgQZ3tQOhkDRRYB8Y
# 1    spotify:artist:3ggwAqZD3lyT2sbovlmfQY
# 2    spotify:artist:6d24kC5fxHFOSEAmjQPPhc
# 3    spotify:artist:2UoOdQyBGyzrEfxcY77ce0
# 4    spotify:artist:3ALVPmg5sZexSVD2m9atEt
# ..                                     ...
# 247  spotify:artist:60FBOUJSsvKm0RLhW6UrnB
# 248  spotify:artist:3NbAdx97xTYR4fTi2FTcJb
# 249  spotify:artist:5cnKnd0LgyiMrx4IrY8QxC
# 250  spotify:artist:0p3b6cLQtA5NUKziiSp6bS
# 251  spotify:artist:1rEaptxYcC3endZKREabtN
#
# [252 rows x 5 columns]

# %%
df_METAL_artists.loc[df_METAL_artists['Name']=='Masacre']
# Out:
# Empty DataFrame
# Columns: [Name, Genres, Popularity, Followers, Artist_URI]
# Index: []

# %%
df_METAL_artists.loc[df_METAL_artists['Name']=='Suffocation']
# Out:
# Empty DataFrame
# Columns: [Name, Genres, Popularity, Followers, Artist_URI]
# Index: []

# %%
#df_METAL_artists.to_csv('Spotify_extracted.csv',index=False)

# %%
df_METAL_artists.loc[df_METAL_artists['Name']=='Blood May Rise']
# Out:
# Empty DataFrame
# Columns: [Name, Genres, Popularity, Followers, Artist_URI]
# Index: []

# %%
def get_markets(access_token, limit=50, offset=0):
    markets_url = 'https://api.spotify.com/v1/browse/categories'
    
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    
    params = {
        'limit': limit,
        'offset': offset
    }
    
    # Realiza la petición GET a la API de Spotify para obtener los géneros
    response = requests.get(markets_url, headers=headers, params=params)
    
    # Extrae la respuesta y convierte el JSON en un diccionario de Python
    markets_data = response.json()
    
    # Crea una lista de tuplas, donde cada tupla contiene el ID del género y su nombre
    markets = [(category['id'], category['name']) for category in markets_data['categories']['items']]
    
    return markets

# %%
access_token = get_access_token(client_id, client_secret)  # Suponiendo que ya has definido client_id y client_secret
markets_list = get_markets(access_token)

# Crear un DataFrame a partir de la lista de géneros
df_markets = pd.DataFrame(markets_list, columns=['Market_ID', 'Market_Name'])

# 48  0JQ5DAqbMKFRieVZLLoo9m        Instrumental
# 49  0JQ5DAqbMKFLjmiZRss79w             Ambient

# %%
def get_artists_by_name(query, access_token, limit=50):
    search_url = 'https://api.spotify.com/v1/search'
    
    headers = {
        'Authorization': f'Bearer {access_token}'
    }
    
    params = {
        'q': f"name:\"{query}\"",
        'type': 'artist',
        'limit': limit
    }
    
    response = requests.get(search_url, headers=headers, params=params)
    response_data = response.json()
    
    if 'artists' in response_data:
        return [artist['id'] for artist in response_data['artists']['items']]
    else:
        print("Error en la respuesta de la API:", response_data)
        return []

# %%
name = "Ennui Bogotá"
names = get_artists_by_name(name, access_token)
print(names)
# Out:
# ['65uP1jjzWh4VISZCA4s3X7', '7yPL3VXJFaDu9HW6Zou7C5', '2tJE40GixcEoh9zwoBD07H', '0YzIPXT3M4HQxjrYCAgoyD', '64iLtTMfnTAuuMbRk66boJ', '3QX2056UzF995PicCTCsfr', '5AB3ONEZzBBSvjYYStYgap', '3UxjBvP0pvz35UevSs25eh', '5JDM5S7eyY3ypNOyS5e0ML', '0axxjRxJBx2ciiPYRcBPJ2', '0I4flbOXVYUts2wY3cPt1R', '2LXgEluAGEdhhBqTYtve0g', '4lqBkVmOyYfnDQCm5mA5ko', '59mntshH5MOPANbk9f69hP', '3ntNlXR1aenb9hNEL02WYH', '0KIxr4HfjzUEBKy6vlfR9O', '08cAZWaoVZnCrDCDY6P7tk', '7sUmD0wgjQR7cavOCCdP5W', '0hKhw4tF73tq6390kUouxM', '1qo7mKjITlrCOs9nptnPEb', '2JTmMIiuyMwoO9nvPoZJ2Z']

# %%
token=access_token
# Obtener respuesta de la API
response_data_names = get_artists_from_spotify(token, names)

# Procesar la respuesta con la función extract_artists_to_dataframe
df_metal_artist_names = extract_artists_to_dataframe(response_data_names)
#print(df)
df_metal_artist_names
# Out:
#                                                  Name           Genres  \
# 0   Paid Master Received Contract Signed Editor St...
# 1                                    Bogotá Rich iNDo
# 2                                         10NamesJune
# 3                                      Bogotaenelmapa
# 4                                           1000names
# 5                                         Bogotá Boys
# 6                                        119 No Names
# 7                                        Ennui Bogotá
# 8                                           1000names
# 9                                           NAMELESS1
# 10                                     Namesake 106:8
# 11                                         2Rons1Name
# 12                                            NAME101
# 13       J. Money 1st Name Last Name (mr. Futuristic)  futuristic swag
# 14                                         1000 Names
# 15                                           10 Names
# 16                                         10namejune
# 17                                            13NAMES
# 18                                    Dj 100names Clo
# 19                                         Norma1Name
# 20                                      deleted_name1
#
#     Popularity                                        Spotify_URL  Followers  \
# 0            0  https://open.spotify.com/artist/65uP1jjzWh4VIS...         46
# 1            4  https://open.spotify.com/artist/7yPL3VXJFaDu9H...          2
# 2            0  https://open.spotify.com/artist/2tJE40GixcEoh9...         27
# 3            1  https://open.spotify.com/artist/0YzIPXT3M4HQxj...          6
# 4            3  https://open.spotify.com/artist/64iLtTMfnTAuuM...       1980
# 5            6  https://open.spotify.com/artist/3QX2056UzF995P...        267
# 6            0  https://open.spotify.com/artist/5AB3ONEZzBBSvj...         43
# 5       artist  spotify:artist:3QX2056UzF995PicCTCsfr
# 6       artist  spotify:artist:5AB3ONEZzBBSvjYYStYgap
# 7       artist  spotify:artist:3UxjBvP0pvz35UevSs25eh
# 8       artist  spotify:artist:5JDM5S7eyY3ypNOyS5e0ML
# 9       artist  spotify:artist:0axxjRxJBx2ciiPYRcBPJ2
# 10      artist  spotify:artist:0I4flbOXVYUts2wY3cPt1R
# 11      artist  spotify:artist:2LXgEluAGEdhhBqTYtve0g
# 12      artist  spotify:artist:4lqBkVmOyYfnDQCm5mA5ko
# 13      artist  spotify:artist:59mntshH5MOPANbk9f69hP
# 14      artist  spotify:artist:3ntNlXR1aenb9hNEL02WYH
# 15      artist  spotify:artist:0KIxr4HfjzUEBKy6vlfR9O
# 16      artist  spotify:artist:08cAZWaoVZnCrDCDY6P7tk
# 17      artist  spotify:artist:7sUmD0wgjQR7cavOCCdP5W
# 18      artist  spotify:artist:0hKhw4tF73tq6390kUouxM
# 19      artist  spotify:artist:1qo7mKjITlrCOs9nptnPEb
# 20      artist  spotify:artist:2JTmMIiuyMwoO9nvPoZJ2Z

# %%
df_metal_artist_names.loc[df_metal_artist_names['Name']=='Ennui Bogotá']
# Out:
#            Name Genres  Popularity  \
# 7  Ennui Bogotá                  2
#
#                                          Spotify_URL  Followers  \
# 7  https://open.spotify.com/artist/3UxjBvP0pvz35U...        180
#
#                                            Image_URL               Artist_ID  \
# 7  https://i.scdn.co/image/ab6761610000e5eb15e0c5...  3UxjBvP0pvz35UevSs25eh
#
#   Artist_Type                             Artist_URI
# 7      artist  spotify:artist:3UxjBvP0pvz35UevSs25eh

# %%
def get_tracks_from_id(token, artist_ids, batch_size=50):
    """
    Fetch artist details from Spotify's API in batches.
    
    :param access_token: Token for API authorization.
    :param artist_ids: List of artist IDs.
    :param batch_size: Size of the artist ID batches to request.
    :return: List of artist data dictionaries.
    """
    # Endpoint de la API
    base_url = "https://api.spotify.com/v1/tracks"
    
    # Lista para almacenar todos los datos de los artistas
    all_artist_tracks = []
    
    # Dividir la lista de IDs en batches
    for i in range(0, len(artist_ids), batch_size):
        batch = artist_ids[i:i+batch_size]
        
        # Headers de la petición (incluye el token de acceso para autorización)
        headers = {
            "Authorization": f"Bearer {token}"
        }
        
        # Parámetros de la petición (IDs de los artistas)
        params = {
            "ids": ",".join(batch)
        }
        
        # Realizar la petición GET a la API de Spotify
        response = requests.get(base_url, headers=headers, params=params)
        
        # Verificar el estado de la respuesta
        if response.status_code == 200:
            # Convertir la respuesta en formato JSON a un diccionario de Python
            batch_data = response.json()
            all_artist_tracks.extend(batch_data['tracks'])
        else:
            print(f"Error en el batch {i//batch_size}: {response.status_code}")
            sleep(1)  # Esperar un segundo antes de continuar para no sobrecargar la API
        
    return all_artist_tracks

# %%
artist_ids=['3UxjBvP0pvz35UevSs25eh']
df_batch_tracks = get_tracks_from_id(token,artist_ids)

# %%
df_batch_tracks
# Out:
# [None]

# %%
def get_albums_from_artist_id(token, artist_id):
    """
    Fetch albums from an artist from Spotify's API.
    
    :param token: Token for API authorization.
    :param artist_id: Artist ID.
    :return: List of album IDs.
    """
    albums_url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = {"Authorization": f"Bearer {token}"}
    response = requests.get(albums_url, headers=headers)
    
    if response.status_code == 200:
        albums_data = response.json()
        return [album['id'] for album in albums_data['items']]
    else:
        print(f"Error fetching albums: {response.status_code}")
        return []

def get_tracks_from_album_ids(token, album_ids):
    """
    Fetch tracks from album IDs from Spotify's API.
    
    :param token: Token for API authorization.
    :param album_ids: List of album IDs.
    :return: List of track data dictionaries.
    """
    all_tracks = []
    for album_id in album_ids:
        tracks_url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
        headers = {"Authorization": f"Bearer {token}"}
        response = requests.get(tracks_url, headers=headers)
        
        if response.status_code == 200:
            tracks_data = response.json()
            all_tracks.extend(tracks_data['items'])
        else:
            print(f"Error fetching tracks for album {album_id}: {response.status_code}")
    
    return all_tracks

# %%
# Ejemplo de uso
artist_id = '3UxjBvP0pvz35UevSs25eh'
album_ids = get_albums_from_artist_id(token, artist_id)
tracks = get_tracks_from_album_ids(token, album_ids)

# %%
tracks_df=pd.DataFrame(tracks)

# %%
tracks_df
# Out:
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
# 20  [{'external_urls': {'spotify': 'https://open.s...
# 21  [{'external_urls': {'spotify': 'https://open.s...
# 22  [{'external_urls': {'spotify': 'https://open.s...
# 23  [{'external_urls': {'spotify': 'https://open.s...
# 24  [{'external_urls': {'spotify': 'https://open.s...
# 25  [{'external_urls': {'spotify': 'https://open.s...
# 26  [{'external_urls': {'spotify': 'https://open.s...
# 27  [{'external_urls': {'spotify': 'https://open.s...
# 28  [{'external_urls': {'spotify': 'https://open.s...
# 29  [{'external_urls': {'spotify': 'https://open.s...
# 30  [{'external_urls': {'spotify': 'https://open.s...
# 31  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 5   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 6   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 7   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 8   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 9   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 10  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 11  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 12  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 13  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 14  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 15  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 16  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 17  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 18  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 19  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 20  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 21  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 22  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 23  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 24  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 25  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 26  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 27  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 28  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 29  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 30  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 31  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#     duration_ms  explicit                                      external_urls  \
# 0        234050     False  {'spotify': 'https://open.spotify.com/track/63...
# 1        297000     False  {'spotify': 'https://open.spotify.com/track/2X...
# 2        236228     False  {'spotify': 'https://open.spotify.com/track/3M...
# 3        173391     False  {'spotify': 'https://open.spotify.com/track/2R...
# 4        268335     False  {'spotify': 'https://open.spotify.com/track/10...
# 5        332524     False  {'spotify': 'https://open.spotify.com/track/6s...
# 6        167973     False  {'spotify': 'https://open.spotify.com/track/26...
# 7        256877      True  {'spotify': 'https://open.spotify.com/track/0J...
# 8        339955     False  {'spotify': 'https://open.spotify.com/track/6R...
# 9        350740      True  {'spotify': 'https://open.spotify.com/track/1J...
# 10       226885     False  {'spotify': 'https://open.spotify.com/track/38...
# 11        73000     False  {'spotify': 'https://open.spotify.com/track/0t...
# 12       227000     False  {'spotify': 'https://open.spotify.com/track/4y...
# 13       169500     False  {'spotify': 'https://open.spotify.com/track/5l...
# 14       218500     False  {'spotify': 'https://open.spotify.com/track/7a...
# 15       316375     False  {'spotify': 'https://open.spotify.com/track/76...
# 16       236750     False  {'spotify': 'https://open.spotify.com/track/2Z...
# 17       229624     False  {'spotify': 'https://open.spotify.com/track/4A...
# 18       349000     False  {'spotify': 'https://open.spotify.com/track/4p...
# 19       315323     False  {'spotify': 'https://open.spotify.com/track/3Q...
# 20       239975     False  {'spotify': 'https://open.spotify.com/track/5p...
# 21       240000     False  {'spotify': 'https://open.spotify.com/track/2k...
# 22       196452     False  {'spotify': 'https://open.spotify.com/track/0u...
# 23       178000     False  {'spotify': 'https://open.spotify.com/track/66...
# 24       196452     False  {'spotify': 'https://open.spotify.com/track/1W...
# 25       299200     False  {'spotify': 'https://open.spotify.com/track/3V...
# 26       266242     False  {'spotify': 'https://open.spotify.com/track/3F...
# 27       299200     False  {'spotify': 'https://open.spotify.com/track/6S...
# 28       178000     False  {'spotify': 'https://open.spotify.com/track/0D...
# 29       180047     False  {'spotify': 'https://open.spotify.com/track/2y...
# 30       248499     False  {'spotify': 'https://open.spotify.com/track/7z...
# 31       223840     False  {'spotify': 'https://open.spotify.com/track/5q...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/63t1moUm7LQC...  63t1moUm7LQCc6NfZp8XaD
# 1   https://api.spotify.com/v1/tracks/2XPblwHwHc8M...  2XPblwHwHc8Mt0cylp4och
# 2   https://api.spotify.com/v1/tracks/3M5RooKCXLXc...  3M5RooKCXLXcooHSE8Hod2
# 3   https://api.spotify.com/v1/tracks/2RXUTKh6Ktq3...  2RXUTKh6Ktq3YdHvtOutDG
# 4   https://api.spotify.com/v1/tracks/10WuK4DTP8lK...  10WuK4DTP8lKzM1pwfVrf3
# 5   https://api.spotify.com/v1/tracks/6sEdiU8fuf8a...  6sEdiU8fuf8a8LPyF4uriQ
# 28  https://p.scdn.co/mp3-preview/a29364dad85b3c94...             1  track
# 29  https://p.scdn.co/mp3-preview/5894e004be56d4bd...             1  track
# 30  https://p.scdn.co/mp3-preview/432e078ebb22be32...             2  track
# 31  https://p.scdn.co/mp3-preview/35895a9bc15d3aae...             3  track
#
#                                      uri
# 0   spotify:track:63t1moUm7LQCc6NfZp8XaD
# 1   spotify:track:2XPblwHwHc8Mt0cylp4och
# 2   spotify:track:3M5RooKCXLXcooHSE8Hod2
# 3   spotify:track:2RXUTKh6Ktq3YdHvtOutDG
# 4   spotify:track:10WuK4DTP8lKzM1pwfVrf3
# 5   spotify:track:6sEdiU8fuf8a8LPyF4uriQ
# 6   spotify:track:26xnsHvGQP931uoFLnSmP2
# 7   spotify:track:0JmlHBAvzPsuvxPidjaLLF
# 8   spotify:track:6R4GF4WPsCrUalphBX3VKt
# 9   spotify:track:1J9VXoWsxYMJ8fL6FPuxP1
# 10  spotify:track:38R7trLDNhiWyZDOzD4TBw
# 11  spotify:track:0tzpv3v0SayCBWV9ZF8mAt
# 12  spotify:track:4ygegWWMWmBCXMltUYGTsp
# 13  spotify:track:5lZ67mFK3mGSrdOgrFm0NN
# 14  spotify:track:7aGijbDrGiQljyhW1uzzPC
# 15  spotify:track:76WBt5RRAKvLRsBBJLKrhY
# 16  spotify:track:2ZMjsACBMYeRLpRwKMuyZK
# 17  spotify:track:4AofPSnl4RAlYXeU545w79
# 18  spotify:track:4pcdv1wHAocUgWEwfRx6e6
# 19  spotify:track:3Qlj3BDgh1eMsIuiKhEv4m
# 20  spotify:track:5p51EGEuPYwfxkdZkxbSHV
# 21  spotify:track:2kBkKNmyWnrGZLhsEXR2ec
# 22  spotify:track:0unxlhrjsG5vyiNErKVPok
# 23  spotify:track:66LjTKT7KWbzbtBU6Par3B
# 24  spotify:track:1WODRX5U7YJZixI6YqRPGG
# 25  spotify:track:3V4ya95TTwAkTK9DxLQ0gc
# 26  spotify:track:3FPIxznZMl5Nq7kGa85sdb
# 27  spotify:track:6SRrgYUVSrnRSlvNplvoTR
# 28  spotify:track:0D2a6GTlKpArqXmNuubGcL
# 29  spotify:track:2yI9DoyZuxryPBBoU15MVR
# 30  spotify:track:7zmDTgJ9e9YfSIPkv83TO1
# 31  spotify:track:5qDr5uKIX6PMYpqo0UfZjF

# %%
BMR_Tracks_List=tracks_df['id'].tolist()

# %%
BMR_Tracks_List
# Out:
# ['63t1moUm7LQCc6NfZp8XaD',
#  '2XPblwHwHc8Mt0cylp4och',
#  '3M5RooKCXLXcooHSE8Hod2',
#  '2RXUTKh6Ktq3YdHvtOutDG',
#  '10WuK4DTP8lKzM1pwfVrf3',
#  '6sEdiU8fuf8a8LPyF4uriQ',
#  '26xnsHvGQP931uoFLnSmP2',
#  '0JmlHBAvzPsuvxPidjaLLF',
#  '6R4GF4WPsCrUalphBX3VKt',
#  '1J9VXoWsxYMJ8fL6FPuxP1',
#  '38R7trLDNhiWyZDOzD4TBw',
#  '0tzpv3v0SayCBWV9ZF8mAt',
#  '4ygegWWMWmBCXMltUYGTsp',
#  '5lZ67mFK3mGSrdOgrFm0NN',
#  '7aGijbDrGiQljyhW1uzzPC',
#  '76WBt5RRAKvLRsBBJLKrhY',
#  '2ZMjsACBMYeRLpRwKMuyZK',
#  '4AofPSnl4RAlYXeU545w79',
#  '4pcdv1wHAocUgWEwfRx6e6',
#  '3Qlj3BDgh1eMsIuiKhEv4m',
#  '5p51EGEuPYwfxkdZkxbSHV',
#  '2kBkKNmyWnrGZLhsEXR2ec',
#  '0unxlhrjsG5vyiNErKVPok',
#  '66LjTKT7KWbzbtBU6Par3B',
#  '1WODRX5U7YJZixI6YqRPGG',
#  '3V4ya95TTwAkTK9DxLQ0gc',
#  '3FPIxznZMl5Nq7kGa85sdb',
#  '6SRrgYUVSrnRSlvNplvoTR',
#  '0D2a6GTlKpArqXmNuubGcL',
#  '2yI9DoyZuxryPBBoU15MVR',
#  '7zmDTgJ9e9YfSIPkv83TO1',
#  '5qDr5uKIX6PMYpqo0UfZjF']

# %%
def get_features_from_tracks(token, tracks_ids, batch_size=50):
    """
    Fetch artist details from Spotify's API in batches.
    
    :param access_token: Token for API authorization.
    :param artist_ids: List of artist IDs.
    :param batch_size: Size of the artist ID batches to request.
    :return: List of artist data dictionaries.
    """
    # Endpoint de la API
    base_url = "https://api.spotify.com/v1/audio-features"
    
    # Lista para almacenar todos los datos de los artistas
    all_tracks_features = []
    
    # Dividir la lista de IDs en batches
    for i in range(0, len(tracks_ids), batch_size):
        batch = tracks_ids[i:i+batch_size]
        
        # Headers de la petición (incluye el token de acceso para autorización)
        headers = {
            "Authorization": f"Bearer {token}"
        }
        
        # Parámetros de la petición (IDs de los artistas)
        params = {
            "ids": ",".join(batch)
        }
        
        # Realizar la petición GET a la API de Spotify
        response = requests.get(base_url, headers=headers, params=params)
        
        # Verificar el estado de la respuesta
        if response.status_code == 200:
            # Convertir la respuesta en formato JSON a un diccionario de Python
            batch_data = response.json()
            all_tracks_features.extend(batch_data['audio_features'])
        else:
            print(f"Error en el batch {i//batch_size}: {response.status_code}")
            sleep(1)  # Esperar un segundo antes de continuar para no sobrecargar la API
        
    return all_tracks_features

# %%
def extract_features_to_dataframe(response_data):
    features_list = []

    # Asumiendo que response_data es una lista de diccionarios
    for audio_features in response_data:
        # Extraer la información relevante
        features_info = {
            'acousticness': audio_features['acousticness'],
            'danceability': audio_features['danceability'],
            'duration_ms': audio_features['duration_ms'],
            'energy': audio_features['energy'],
            'id': audio_features['id'],
            'instrumentalness': audio_features['instrumentalness'],
            'liveness': audio_features['liveness'],
            'loudness': audio_features['loudness'],
            'speechiness': audio_features['speechiness'],
            'valence': audio_features['valence'],
        }
        # Agregar a la lista
        features_list.append(features_info)

    # Convertir lista en DataFrame
    df_tracks_features = pd.DataFrame(features_list)

    return df_tracks_features

# %%
batch_size = 50  # Spotify API limit
df_BMR_Features = pd.DataFrame()  # DataFrame vacío para almacenar los datos

# Procesar los artist IDs en batches
for i in range(0, len(BMR_Tracks_List), batch_size):
    batch_ids = BMR_Tracks_List[i:i+batch_size]
    batch_data = get_features_from_tracks(token, batch_ids, batch_size)
    df_batch = extract_features_to_dataframe(batch_data)  # Asumiendo que esta función ya está definida
    df_BMR_Features = pd.concat([df_BMR_Features, df_batch], ignore_index=True)

# %%
df_BMR_Features
# Out:
#     acousticness  danceability  duration_ms  energy                      id  \
# 0       0.000918         0.302       234051   0.977  63t1moUm7LQCc6NfZp8XaD
# 1       0.000657         0.428       297000   0.965  2XPblwHwHc8Mt0cylp4och
# 2       0.001320         0.300       236229   0.976  3M5RooKCXLXcooHSE8Hod2
# 3       0.000060         0.300       173391   0.973  2RXUTKh6Ktq3YdHvtOutDG
# 4       0.000270         0.428       268335   0.974  10WuK4DTP8lKzM1pwfVrf3
# 5       0.000023         0.296       332524   0.953  6sEdiU8fuf8a8LPyF4uriQ
# 6       0.000228         0.331       167973   0.980  26xnsHvGQP931uoFLnSmP2
# 7       0.013100         0.453       256878   0.986  0JmlHBAvzPsuvxPidjaLLF
# 8       0.043700         0.380       339956   0.798  6R4GF4WPsCrUalphBX3VKt
# 9       0.009700         0.234       350741   0.997  1J9VXoWsxYMJ8fL6FPuxP1
# 10      0.000494         0.451       226886   0.942  38R7trLDNhiWyZDOzD4TBw
# 11      0.964000         0.356        73000   0.571  0tzpv3v0SayCBWV9ZF8mAt
# 12      0.000050         0.339       227000   0.814  4ygegWWMWmBCXMltUYGTsp
# 13      0.000025         0.292       169500   0.774  5lZ67mFK3mGSrdOgrFm0NN
# 14      0.000588         0.166       218500   0.896  7aGijbDrGiQljyhW1uzzPC
# 15      0.000273         0.216       316375   0.609  76WBt5RRAKvLRsBBJLKrhY
# 16      0.000012         0.184       236750   0.820  2ZMjsACBMYeRLpRwKMuyZK
# 17      0.000362         0.277       229625   0.638  4AofPSnl4RAlYXeU545w79
# 18      0.000283         0.326       349000   0.425  4pcdv1wHAocUgWEwfRx6e6
# 19      0.001510         0.619       315323   0.578  3Qlj3BDgh1eMsIuiKhEv4m
# 20      0.000131         0.482       239975   0.964  5p51EGEuPYwfxkdZkxbSHV
# 21      0.000887         0.299       240000   0.792  2kBkKNmyWnrGZLhsEXR2ec
# 22      0.001190         0.394       196453   0.915  0unxlhrjsG5vyiNErKVPok
# 23      0.000095         0.560       178000   0.929  66LjTKT7KWbzbtBU6Par3B
# 24      0.001190         0.394       196453   0.915  1WODRX5U7YJZixI6YqRPGG
# 25      0.008350         0.548       299200   0.617  3V4ya95TTwAkTK9DxLQ0gc
# 26      0.178000         0.577       266243   0.557  3FPIxznZMl5Nq7kGa85sdb
# 27      0.008060         0.551       299200   0.613  6SRrgYUVSrnRSlvNplvoTR
# 28      0.000093         0.559       178000   0.925  0D2a6GTlKpArqXmNuubGcL
# 29      0.000087         0.382       180048   0.928  2yI9DoyZuxryPBBoU15MVR
# 30      0.000320         0.219       248500   0.919  7zmDTgJ9e9YfSIPkv83TO1
# 31      0.000086         0.162       223840   0.912  5qDr5uKIX6PMYpqo0UfZjF
#
#     instrumentalness  liveness  loudness  speechiness  valence
# 0           0.039600    0.4600    -3.386       0.0692   0.3220
# 1           0.009530    0.9640    -2.808       0.0674   0.1180
# 2           0.572000    0.3730    -2.767       0.0867   0.2410
# 3           0.751000    0.8400    -3.075       0.0747   0.6530
# 4           0.708000    0.9460    -3.506       0.1350   0.2080
# 5           0.874000    0.9830    -2.693       0.0716   0.4570
# 6           0.578000    0.9720    -3.052       0.2040   0.4360
# 7           0.000655    0.4580    -2.697       0.2240   0.1680
# 8           0.849000    0.7090    -2.672       0.0361   0.2240
# 9           0.075100    0.7080    -1.703       0.1910   0.0867
# 10          0.635000    0.4050    -3.919       0.1170   0.2320
# 11          0.879000    0.1040   -15.218       0.1100   0.4990
# 12          0.002020    0.0624   -10.346       0.0670   0.5180
# 13          0.005930    0.1080   -11.204       0.0419   0.6560
# 14          0.000000    0.3410    -9.837       0.0887   0.2230
# 15          0.002900    0.1770   -11.237       0.0317   0.3830
# 16          0.221000    0.1440   -11.326       0.0529   0.1490
# 17          0.000270    0.0974   -11.087       0.0419   0.4190
# 18          0.915000    0.1350   -13.137       0.0371   0.2370
# 19          0.694000    0.1320    -8.957       0.0332   0.2080
# 20          0.126000    0.0607    -5.287       0.0741   0.3840
# 21          0.462000    0.1750    -9.127       0.0391   0.2610
# 22          0.006600    0.0980    -5.898       0.1060   0.5260
# 23          0.000065    0.3510    -5.371       0.1010   0.9600
# 24          0.006600    0.0980    -5.898       0.1060   0.5260
# 25          0.009930    0.0892    -9.148       0.0333   0.4920
# 26          0.324000    0.1060   -15.130       0.0322   0.4860
# 27          0.010200    0.0877    -9.145       0.0324   0.4830
# 28          0.000067    0.3520    -5.381       0.1000   0.9510
# 29          0.146000    0.1070    -7.265       0.1280   0.3850
# 30          0.177000    0.0894    -6.619       0.0581   0.2300
# 31          0.007380    0.0898    -6.717       0.0909   0.3620

# %%
# Usando una paleta de colores que varía con una variable numérica
sns.scatterplot(data=df_BMR_Features, x='energy', y='valence', hue='loudness', palette='coolwarm')

# Mostrar el gráfico
plt.show()

# %%
# Ajustando la opacidad y el tamaño de los puntos
sns.scatterplot(data=df_BMR_Features, x='energy', y='valence', hue='duration_ms', palette='viridis', alpha=0.7, size=10)

# Mostrar el gráfico
plt.show()

# %%
df_BMR_Features['duration_ms'].describe()
# Out:
# count        32.000000
# mean     242654.656250
# std       63468.463094
# min       73000.000000
# 25%      196453.000000
# 50%      236489.500000
# 75%      297550.000000
# max      350741.000000
# Name: duration_ms, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convertir 'duration_ms' a categorías
bins = [0, 180000, 300000, max(df_BMR_Features['duration_ms'])]  # Ejemplo de límites en milisegundos
labels = ['Corto', 'Medio', 'Largo']
df_BMR_Features['duration_category'] = pd.cut(df_BMR_Features['duration_ms'], bins=bins, labels=labels)

# %%
# Crear un displot con hue basado en las categorías de duración
g=sns.displot(data=df_BMR_Features, x='valence', hue='duration_category', kind='kde', palette='viridis')
g.fig.suptitle('Distribución de la Valencia por Duración de Canciones para la banda "Ennui Bogotá"', y=1.03)
plt.tight_layout()
plt.savefig('ennui.png')
plt.show()
